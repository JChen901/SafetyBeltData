# %%
############################
### kleisin_fix_part_HEAT###
############################ 
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as ticker

# 定义格式化函数，将纵轴数字转为整数并乘以10的3次方
def y_formatter(x, pos):
    return f'{int(x / 1000)}'  # 除以1000并显示整数

# read force from the two .xvg files
data1x = np.loadtxt('/data/jychen/MD_projects/SMC/All_Atoms/SteeredMD/2SMD_1protonataing/1/pull_pullx.xvg', comments=['@', '#'])
data2x = np.loadtxt('/data/jychen/MD_projects/SMC/All_Atoms/SteeredMD/2SMD_1protonataing/2/pull_pullx.xvg', comments=['@', '#'])
data3x = np.loadtxt('/data/jychen/MD_projects/SMC/All_Atoms/SteeredMD/2SMD_1protonataing/3/pull_pullx.xvg', comments=['@', '#'])
data4x = np.loadtxt('/data/jychen/MD_projects/SMC/All_Atoms/SteeredMD/2SMD_1protonataing+DNA/1/pull_pullx.xvg', comments=['@', '#'])
data5x = np.loadtxt('/data/jychen/MD_projects/SMC/All_Atoms/SteeredMD/2SMD_1protonataing+DNA/2/pull_pullx.xvg', comments=['@', '#'])
data6x = np.loadtxt('/data/jychen/MD_projects/SMC/All_Atoms/SteeredMD/2SMD_1protonataing+DNA/3/pull_pullx.xvg', comments=['@', '#'])
data7x = np.loadtxt('/data/jychen/MD_projects/SMC/All_Atoms/SteeredMD/2SMD_1protonataing+DNA/1/pull_pullx.xvg', comments=['@', '#'])
data8x = np.loadtxt('/data/jychen/MD_projects/SMC/All_Atoms/SteeredMD/2SMD_1protonataing+DNA/2/pull_pullx.xvg', comments=['@', '#'])
data9x = np.loadtxt('/data/jychen/MD_projects/SMC/All_Atoms/SteeredMD/2SMD_1protonataing+DNA/3/pull_pullx.xvg', comments=['@', '#'])
data10x = np.loadtxt('/data/jychen/MD_projects/SMC/All_Atoms/SteeredMD/2SMD_1protonataing+DNA/1/pull_pullx.xvg', comments=['@', '#'])
data11x = np.loadtxt('/data/jychen/MD_projects/SMC/All_Atoms/SteeredMD/2SMD_1protonataing+DNA/2/pull_pullx.xvg', comments=['@', '#'])
data12x = np.loadtxt('/data/jychen/MD_projects/SMC/All_Atoms/SteeredMD/2SMD_1protonataing+DNA/3/pull_pullx.xvg', comments=['@', '#'])

# read distance from the .xvg file
data1y = np.loadtxt('/data/jychen/MD_projects/SMC/All_Atoms/SteeredMD/2SMD_1protonataing/analysis/contact_number/openPart-fix+HEAT/1.xvg', comments=['@', '#'])
data2y = np.loadtxt('/data/jychen/MD_projects/SMC/All_Atoms/SteeredMD/2SMD_1protonataing/analysis/contact_number/openPart-fix+HEAT/2.xvg', comments=['@', '#'])
data3y = np.loadtxt('/data/jychen/MD_projects/SMC/All_Atoms/SteeredMD/2SMD_1protonataing/analysis/contact_number/openPart-fix+HEAT/3.xvg', comments=['@', '#'])
data4y = np.loadtxt('/data/jychen/MD_projects/SMC/All_Atoms/SteeredMD/2SMD_1protonataing+DNA/analysis/contact_number/openPart-fix+HEAT+DNA/1.xvg', comments=['@', '#'])
data5y = np.loadtxt('/data/jychen/MD_projects/SMC/All_Atoms/SteeredMD/2SMD_1protonataing+DNA/analysis/contact_number/openPart-fix+HEAT+DNA/2.xvg', comments=['@', '#'])
data6y = np.loadtxt('/data/jychen/MD_projects/SMC/All_Atoms/SteeredMD/2SMD_1protonataing+DNA/analysis/contact_number/openPart-fix+HEAT+DNA/3.xvg', comments=['@', '#'])
data7y = np.loadtxt('/data/jychen/MD_projects/SMC/All_Atoms/SteeredMD/2SMD_1protonataing+DNA/analysis/contact_number/openPart-fix+HEAT/1.xvg', comments=['@', '#'])
data8y = np.loadtxt('/data/jychen/MD_projects/SMC/All_Atoms/SteeredMD/2SMD_1protonataing+DNA/analysis/contact_number/openPart-fix+HEAT/2.xvg', comments=['@', '#'])
data9y = np.loadtxt('/data/jychen/MD_projects/SMC/All_Atoms/SteeredMD/2SMD_1protonataing+DNA/analysis/contact_number/openPart-fix+HEAT/3.xvg', comments=['@', '#'])
data10y = np.loadtxt('/data/jychen/MD_projects/SMC/All_Atoms/SteeredMD/2SMD_1protonataing+DNA/analysis/contact_number/openPart-DNA/1.xvg', comments=['@', '#'])
data11y = np.loadtxt('/data/jychen/MD_projects/SMC/All_Atoms/SteeredMD/2SMD_1protonataing+DNA/analysis/contact_number/openPart-DNA/2.xvg', comments=['@', '#'])
data12y = np.loadtxt('/data/jychen/MD_projects/SMC/All_Atoms/SteeredMD/2SMD_1protonataing+DNA/analysis/contact_number/openPart-DNA/3.xvg', comments=['@', '#'])

#extract data every 500 points
data1=data1x[0:24530:500]
data2=data1y[0:2453:50]
data3=data2x[0:24530:500]
data4=data2y[0:2453:50]
data5=data3x[0:24530:500]
data6=data3y[0:2453:50]
data7=data4x[0:24530:500]
data8=data4y[0:2453:50]
data9=data5x[0:24530:500]
data10=data5y[0:2453:50]
data11=data6x[0:24530:500]
data12=data6y[0:2453:50]
data13=data7x[0:24530:500]
data14=data7y[0:2453:50]
data15=data8x[0:24530:500]
data16=data8y[0:2453:50]
data17=data9x[0:24530:500]
data18=data9y[0:2453:50]
data19=data10x[0:24530:500]
data20=data10y[0:2452:50]
data21=data11x[0:24530:500]
data22=data11y[0:2453:50]
data23=data12x[0:24530:500]
data24=data12y[0:2453:50]


# extract x and y data from the files
xdata1 = data1[:, 1]
ydata1 = data2[:, 1]
xdata2 = data3[:, 1]
ydata2 = data4[:, 1]
xdata3 = data5[:, 1]
ydata3 = data6[:, 1]
xdata4 = data7[:, 1]
ydata4 = data8[:, 1]
xdata5 = data9[:, 1]
ydata5 = data10[:, 1]
xdata6 = data11[:, 1]
ydata6 = data12[:, 1]
xdata7 = data13[:, 1]
ydata7 = data14[:, 1]
xdata8 = data15[:, 1]
ydata8 = data16[:, 1]
xdata9 = data17[:, 1]
ydata9 = data18[:, 1]
xdata10 = data19[:, 1]
ydata10 = data20[:, 1]
xdata11 = data21[:, 1]
ydata11 = data22[:, 1]
xdata12 = data23[:, 1]
ydata12 = data24[:, 1]

# 创建一个新的列表来存储每帧的平均值和误差棒
average_values1 = []
errors1 = []

# 创建一个新的列表来存储第二组数据每帧的平均值和误差棒
average_values2 = []
errors2 = []

# 创建一个新的列表来存储第三组数据每帧的平均值和误差棒
average_values3 = []
errors3 = []

# 创建一个新的列表来存储第四组数据每帧的平均值和误差棒
average_values4 = []
errors4 = []

# 遍历每一帧的数据
for i in range(len(xdata1)):
    # 对应位置的元素相加并求平均值，计算误差棒，第一组数据
    average = (ydata1[i] + ydata2[i] + ydata3[i]) / 3
    error = np.std([ydata1[i], ydata2[i], ydata3[i]]) / np.sqrt(3)

    # 对应位置的元素相加并求平均值，计算误差棒，第二组数据
    average2 = (ydata4[i] + ydata5[i] + ydata6[i]) / 3
    error2 = np.std([ydata4[i], ydata5[i], ydata6[i]]) / np.sqrt(3)

    # 对应位置的元素相加并求平均值，计算误差棒，第三组数据
    average3 = (ydata7[i] + ydata8[i] + ydata9[i]) / 3
    error3 = np.std([ydata7[i], ydata8[i], ydata9[i]]) / np.sqrt(3)

    average4 = (ydata10[i] + ydata11[i] + ydata12[i]) / 3
    error4 = np.std([ydata10[i], ydata11[i], ydata12[i]]) / np.sqrt(3)
    
    # 将计算得到的平均值和误差棒存储到新的列表中
    average_values1.append(average)
    errors1.append(error)

    # 将计算得到的平均值和误差棒存储到新的列表中
    average_values2.append(average2)
    errors2.append(error2)

    # 将计算得到的平均值和误差棒存储到新的列表中
    average_values3.append(average3)
    errors3.append(error3)

    # 将计算得到的平均值和误差棒存储到新的列表中
    average_values4.append(average4)
    errors4.append(error4)


# 设置全局字体
plt.rcParams.update({
    'font.family': 'Arial',  # 设置字体
    'axes.titlesize': 36,  # 标题字体大小
    'axes.labelsize': 36,  # 坐标轴标签字体大小
    'xtick.labelsize': 36,  # X轴刻度字体大小
    'ytick.labelsize': 36,  # Y轴刻度字体大小
    'legend.fontsize': 36,  # 图例字体大小
    'figure.figsize': (8.5, 7),  # 图像大小
    'axes.linewidth': 4,  # 坐标轴线宽
    'xtick.major.size': 10, # x 轴主刻度长度
    'ytick.major.size': 10, # y 轴主刻度长度
    'xtick.minor.size': 5, # x 轴次刻度长度
    'ytick.minor.size': 5, # y 轴主刻度长度
    'xtick.major.width': 4, # x 轴主刻度线宽
    'ytick.major.width': 4, # y 轴主刻度线宽
    'xtick.minor.width': 4, # x 轴次刻度线宽
    'ytick.minor.width': 4, # y 轴主刻度线宽
    'axes.grid': False,  # 关闭背景网格
})

# 绘制图像
fig, ax = plt.subplots(figsize=(8.5, 7))

# 绘制第一组数据（无 DNA）及其阴影误差区域
ax.plot(xdata1, average_values1, color='tab:red', linestyle='-', label='US',linewidth=4)
ax.fill_between(
    xdata1,
    np.array(average_values1) - np.array(errors1),
    np.array(average_values1) + np.array(errors1),
    color='tab:red',
    alpha=0.2,
)

# 绘制第二组数据（有 DNA）及其阴影误差区域
ax.plot(xdata2, average_values2, color='tab:blue', linestyle='-', label=r'$\text{BS (Total)}$',linewidth=4)
ax.fill_between(
    xdata2,
    np.array(average_values2) - np.array(errors2),
    np.array(average_values2) + np.array(errors2),
    color='tab:blue',
    alpha=0.2,
)

# 绘制第三组数据（另一条件）及其阴影误差区域
ax.plot(xdata3, average_values3, color='tab:green', linestyle='-', label=r'$\text{BS (Protein)}$',linewidth=4)
ax.fill_between(
    xdata3,
    np.array(average_values3) - np.array(errors3),
    np.array(average_values3) + np.array(errors3),
    color='tab:green',
    alpha=0.2,
)

# 绘制第四组数据（另一条件）及其阴影误差区域
ax.plot(xdata4, average_values4, color='tab:purple', linestyle='-', label=r'$\text{BS (DNA)}$',linewidth=4)
ax.fill_between(
    xdata4,
    np.array(average_values4) - np.array(errors4),
    np.array(average_values4) + np.array(errors4),
    color='tab:purple',
    alpha=0.2,
)

# 设置坐标轴标签和标题
ax.set_xlabel('Distance (nm)')
ax.set_ylabel(r'Contact number ($\times 10^3$)')
#ax.set_title('Contact_number with Distance')

# 在12-14区间添加背景色以突出显示
ax.axvspan(11, 14, color='tab:orange', alpha=0.3)

# 加粗刻度字体
#plt.setp(ax.get_xticklabels(), fontweight='bold')
#plt.setp(ax.get_yticklabels(), fontweight='bold')

# x 轴刻度朝内
ax.tick_params(axis='x', which='both', direction='in')
# y 轴刻度朝内
ax.tick_params(axis='y', which='both', direction='in')

ax.yaxis.set_major_formatter(ticker.FuncFormatter(y_formatter))

# 调整横坐标和纵坐标间隔
ax.xaxis.set_major_locator(ticker.MultipleLocator(3))  # 横坐标主刻度间隔
#ax.xaxis.set_minor_locator(ticker.MultipleLocator(1))  # 横坐标次刻度间隔
ax.yaxis.set_major_locator(ticker.MultipleLocator(3000))  # 纵坐标主刻度间隔
#ax.yaxis.set_minor_locator(ticker.MultipleLocator(1000))  # 纵坐标次刻度间隔

# 添加网格线
#ax.grid(visible=True, which='major', linestyle='--', linewidth=0.5, alpha=0.7)

# 添加图例
ax.legend(loc='upper right',bbox_to_anchor=(1.06, 1.05),frameon=False,handlelength=0,labelcolor='linecolor')

ax.set_xlim(1, 15)
ax.set_ylim(0, 14000)

# 调整图形边距
plt.subplots_adjust(left=0.2, right=0.9, top=0.9, bottom=0.15)  # 固定边距

# 保存高分辨率图片
plt.savefig("Contact_number_with_Distance.png", dpi=300)
plt.show()
