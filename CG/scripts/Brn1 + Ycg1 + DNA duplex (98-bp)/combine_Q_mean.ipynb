# %%
#########################
### all_Q_means with time ###
########################## 
import matplotlib.pyplot as plt
import numpy as np

from matplotlib.collections import EventCollection

def calculate_SE(data, groups):
    """
    将数据分成指定数量的组，计算每个组的平均值，然后计算这些平均值的标准误差(SE)。
    """
    n = len(data)
    # 确保能够平均分组
    if n < groups:
        raise ValueError("数据量少于分组数量，无法分组。")
    
    # 计算每组的大小，使用整除 // 来确保得到整数
    group_size = n // groups
    
    # 初始化一个列表来存储每个子组的平均值
    group_means = []
    
    for i in range(groups):
        # 计算每个子组的开始和结束索引
        start_idx = i * group_size
        # 对于最后一个子组，确保包含所有剩余的数据
        if i == groups - 1:
            end_idx = n
        else:
            end_idx = start_idx + group_size
        # 计算子组的平均值并添加到列表中
        group_mean = np.mean(data[start_idx:end_idx])
        group_means.append(group_mean)
    
    # 计算所有子组平均值的标准差，并除以 sqrt(groups) 来计算标准误差
    se = np.std(group_means, ddof=1) / np.sqrt(groups)
    
    return se

QT1 = []
QT1_se = []

Q1t = []
Q1t_se = []
Q2t = []
Q2t_se = []

# read distance from the .xvg file

Q = []
for i in range(10):
    n = int(i + 1)
    data = np.loadtxt(f'/hpc2hdd/home/jchen901/data/genesis/GENESIS_Tutorials-2022/Works/SMC_AICG2+/Kleisin_interaction_test/replica/analysis/Q_mean/0.3_latch/colvar{n}', comments=['@', '#'])
    Q.append(data[:,1])
QT1.append(np.mean(Q))
QT1_se.append(calculate_SE(Q, 10))

# read distance from the .xvg file

Q1=[]
Q2=[]
for i in range(50):
#   if i == 4:
#   continue
    n = int(i + 1)
    data1 = np.loadtxt(f'/hpc2hdd/home/jchen901/data/genesis/GENESIS_Tutorials-2022/Works/SMC_AICG2+/Full_removLig+98bp/021_delPartGo/analysis/para_nonspecific0.6/winding_number_out_para0.6_long/0.3/link_num{n}.txt', comments=['@', '#'])
    data2 = np.loadtxt(f'/hpc2hdd/home/jchen901/data/genesis/GENESIS_Tutorials-2022/Works/SMC_AICG2+/Full_removLig+98bp/021_delPartGo/analysis/para_nonspecific0.6/Q_mean_out_para0.6/0.3_latch/colvar{n}', comments=['@', '#'])
    # combine first m frame data of the N and Q_mean data togather
    data = np.column_stack((data1[:,1],data2[:,1]))
    for j in range(len(data)):
        if data[j,0] < 0.8:
            Q1.append(data[j,1])
        elif data[j,0] >= 0.8:
            Q2.append(data[j,1])
Q1t.append(np.mean(Q1))
Q1t_se.append(calculate_SE(Q1, 10))
Q2t.append(np.mean(Q2))
Q2t_se.append(calculate_SE(Q2, 10))


Q = []
for i in range(10):
    n = int(i + 1)
    data = np.loadtxt(f'/hpc2hdd/home/jchen901/data/genesis/GENESIS_Tutorials-2022/Works/SMC_AICG2+/Kleisin_interaction_test/replica/analysis/Q_mean/0.35_latch/colvar{n}', comments=['@', '#'])
    Q.append(data[:,1])
QT1.append(np.mean(Q))
QT1_se.append(calculate_SE(Q, 10))

# read distance from the .xvg file

Q1=[]
Q2=[]
for i in range(50):
#   if i == 4:
#   continue
    n = int(i + 1)
    data1 = np.loadtxt(f'/hpc2hdd/home/jchen901/data/genesis/GENESIS_Tutorials-2022/Works/SMC_AICG2+/Full_removLig+98bp/021_delPartGo/analysis/para_nonspecific0.6/winding_number_out_para0.6_long/0.35/link_num{n}.txt', comments=['@', '#'])
    data2 = np.loadtxt(f'/hpc2hdd/home/jchen901/data/genesis/GENESIS_Tutorials-2022/Works/SMC_AICG2+/Full_removLig+98bp/021_delPartGo/analysis/para_nonspecific0.6/Q_mean_out_para0.6/0.35_latch/colvar{n}', comments=['@', '#'])
    # combine first m frame data of the N and Q_mean data togather
    data = np.column_stack((data1[:,1],data2[:,1]))
    for j in range(len(data)):
        if data[j,0] < 0.8:
            Q1.append(data[j,1])
        elif data[j,0] >= 0.8:
            Q2.append(data[j,1])
Q1t.append(np.mean(Q1))
Q1t_se.append(calculate_SE(Q1, 10))
Q2t.append(np.mean(Q2))
Q2t_se.append(calculate_SE(Q2, 10))


Q = []
for i in range(10):
    n = int(i + 1)
    data = np.loadtxt(f'/hpc2hdd/home/jchen901/data/genesis/GENESIS_Tutorials-2022/Works/SMC_AICG2+/Kleisin_interaction_test/replica/analysis/Q_mean/0.37_latch/colvar{n}', comments=['@', '#'])
    Q.append(data[:,1])
QT1.append(np.mean(Q))
QT1_se.append(calculate_SE(Q, 10))

# read distance from the .xvg file

Q1=[]
Q2=[]
for i in range(50):
#   if i == 4:
#   continue
    n = int(i + 1)
    data1 = np.loadtxt(f'/hpc2hdd/home/jchen901/data/genesis/GENESIS_Tutorials-2022/Works/SMC_AICG2+/Full_removLig+98bp/021_delPartGo/analysis/para_nonspecific0.6/winding_number_out_para0.6_long/0.37/link_num{n}.txt', comments=['@', '#'])
    data2 = np.loadtxt(f'/hpc2hdd/home/jchen901/data/genesis/GENESIS_Tutorials-2022/Works/SMC_AICG2+/Full_removLig+98bp/021_delPartGo/analysis/para_nonspecific0.6/Q_mean_out_para0.6/0.37_latch/colvar{n}', comments=['@', '#'])
    # combine first m frame data of the N and Q_mean data togather
    data = np.column_stack((data1[:,1],data2[:,1]))
    for j in range(len(data)):
        if data[j,0] < 0.8:
            Q1.append(data[j,1])
        elif data[j,0] >= 0.8:
            Q2.append(data[j,1])
Q1t.append(np.mean(Q1))
Q1t_se.append(calculate_SE(Q1, 10))
Q2t.append(np.mean(Q2))
Q2t_se.append(calculate_SE(Q2, 10))

Q = []
for i in range(10):
    n = int(i + 1)
    data = np.loadtxt(f'/hpc2hdd/home/jchen901/data/genesis/GENESIS_Tutorials-2022/Works/SMC_AICG2+/Kleisin_interaction_test/replica/analysis/Q_mean/0.4_latch/colvar{n}', comments=['@', '#'])
    Q.append(data[:,1])
QT1.append(np.mean(Q))
QT1_se.append(calculate_SE(Q, 10))
 
# read distance from the .xvg file

Q1=[]
Q2=[]
for i in range(50):
#   if i == 4:
#   continue
    n = int(i + 1)
    data1 = np.loadtxt(f'/hpc2hdd/home/jchen901/data/genesis/GENESIS_Tutorials-2022/Works/SMC_AICG2+/Full_removLig+98bp/021_delPartGo/analysis/para_nonspecific0.6/winding_number_out_para0.6_long/0.4/link_num{n}.txt', comments=['@', '#'])
    data2 = np.loadtxt(f'/hpc2hdd/home/jchen901/data/genesis/GENESIS_Tutorials-2022/Works/SMC_AICG2+/Full_removLig+98bp/021_delPartGo/analysis/para_nonspecific0.6/Q_mean_out_para0.6/0.4_latch/colvar{n}', comments=['@', '#'])
    # combine first m frame data of the N and Q_mean data togather
    data = np.column_stack((data1[:,1],data2[:,1]))
    for j in range(len(data)):
        if data[j,0] < 0.8:
            Q1.append(data[j,1])
        elif data[j,0] >= 0.8:
            Q2.append(data[j,1])
Q1t.append(np.mean(Q1))
Q1t_se.append(calculate_SE(Q1, 10))
Q2t.append(np.mean(Q2))
Q2t_se.append(calculate_SE(Q2, 10))

Q = []
for i in range(10):
    n = int(i + 1)
    data = np.loadtxt(f'/hpc2hdd/home/jchen901/data/genesis/GENESIS_Tutorials-2022/Works/SMC_AICG2+/Kleisin_interaction_test/replica/analysis/Q_mean/0.45_latch/colvar{n}', comments=['@', '#'])
    Q.append(data[:,1])
QT1.append(np.mean(Q))
QT1_se.append(calculate_SE(Q, 10))
 
# read distance from the .xvg file

Q1=[]
Q2=[]
for i in range(50):
#   if i == 4:
#   continue
    n = int(i + 1)
    data1 = np.loadtxt(f'/hpc2hdd/home/jchen901/data/genesis/GENESIS_Tutorials-2022/Works/SMC_AICG2+/Full_removLig+98bp/021_delPartGo/analysis/para_nonspecific0.6/winding_number_out_para0.6_long/0.45/link_num{n}.txt', comments=['@', '#'])
    data2 = np.loadtxt(f'/hpc2hdd/home/jchen901/data/genesis/GENESIS_Tutorials-2022/Works/SMC_AICG2+/Full_removLig+98bp/021_delPartGo/analysis/para_nonspecific0.6/Q_mean_out_para0.6/0.45_latch/colvar{n}', comments=['@', '#'])
    # combine first m frame data of the N and Q_mean data togather
    data = np.column_stack((data1[:,1],data2[:,1]))
    for j in range(len(data)):
        if data[j,0] < 0.8:
            Q1.append(data[j,1])
        elif data[j,0] >= 0.8:
            Q2.append(data[j,1])
Q1t.append(np.mean(Q1))
Q1t_se.append(calculate_SE(Q1, 10))
Q2t.append(np.mean(Q2))
Q2t_se.append(calculate_SE(Q2, 10))
print(len(Q2))
# Out:
# 2065279

# %%
import matplotlib.pyplot as plt
import numpy as np

species = ("0.3", "0.35", "0.37", "0.4", "0.45")
penguin_means = {
    r'$\text{S}_{\text{f}}$': QT1,
    r'$\text{S}_{\text{nl}}$': Q1t,
    r'$\text{S}_{\text{l}}$': Q2t,
}
penguin_std = {
    r'$\text{S}_{\text{f}}$': QT1_se,
    r'$\text{S}_{\text{nl}}$': Q1t_se,
    r'$\text{S}_{\text{l}}$': Q2t_se,
}
# 更新绘图风格
plt.rcParams.update({
    'font.family': 'Arial',
    'axes.titlesize': 36,
    'axes.labelsize': 36,
    'xtick.labelsize': 36,
    'ytick.labelsize': 36,
    'legend.fontsize': 36,
    'figure.figsize': (12, 8),
    'axes.linewidth': 4,
    'xtick.major.size': 10, # x 轴主刻度长度
    'ytick.major.size': 10, # y 轴主刻度长度
    'xtick.minor.size': 5, # x 轴次刻度长度
    'ytick.minor.size': 5, # y 轴主刻度长度
    'xtick.major.width': 4,
    'ytick.major.width': 4,
    'xtick.minor.width': 4,
    'ytick.minor.width': 4,
    'axes.grid': False,
})

# 设置柱状图参数
width = 0.25
group_gap = 0.2
x = np.arange(len(species)) * (len(penguin_means) * width + group_gap)

fig, ax = plt.subplots()

multiplier = 0
top_points = []

colors = ['#C0C0C0', '#25387F', '#F5BC1F']  # 根据需要调整颜色

for attribute, measurement in penguin_means.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute, capsize=5, 
                   yerr=penguin_std[attribute], color=colors[multiplier],error_kw={'elinewidth': 2.5,'capthick': 2.5}, edgecolor='black',linewidth=4)
    
#    labels = ax.bar_label(rects, padding=3, fmt='%.2f', fontsize=20)
#    for label in labels:
#        label.set_rotation(30)
    
    if multiplier == len(penguin_means) - 1:
        for rect in rects:
            top_points.append((rect.get_x() + rect.get_width() / 2, rect.get_height()))
    
    multiplier += 1

x_coords = [point[0] for point in top_points]
y_coords = [point[1] for point in top_points]

ax.set_xlabel(r'$\epsilon_\text{LB}$', labelpad=10)
ax.set_ylabel('Q', labelpad=10)
ax.set_title(r'$\epsilon_\text{HD}$ = 0.6',pad = 15)
ax.set_xticks(x + (len(penguin_means) - 1) * width / 2, species)
ax.legend(loc='best', ncols=1, frameon=False)

#ax.set_yscale('log')
ax.set_ylim(0, 1.05)
ax.set_yticks ([0, 0.5, 1])

# x 轴刻度朝内
plt.tick_params(axis='x', which='both', direction='out')
# y 轴刻度朝内
plt.tick_params(axis='y', which='both', direction='in')

fig.tight_layout(pad=2)

#plt.savefig(r"QMEAN0.6.png", dpi=300, bbox_inches='tight')
plt.show()
